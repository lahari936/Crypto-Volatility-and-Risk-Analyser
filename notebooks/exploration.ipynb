# %%
from src.data_fetcher import load_crypto_csv
from src.data_processor import compute_log_returns
from src.visualizations import plot_price, plot_volatility

btc = compute_log_returns(load_crypto_csv("bitcoin.csv"))

plot_price(btc, "Bitcoin")
plot_volatility(btc, "Bitcoin")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.data_fetcher import load_crypto_csv
#       2 from src.data_processor import compute_log_returns
#       3 from src.visualizations import plot_price, plot_volatility
#
# ModuleNotFoundError: No module named 'src'
